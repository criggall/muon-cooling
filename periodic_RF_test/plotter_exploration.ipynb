# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

from functions.read_g4bl_data import readDetData
from functions.set_plot_settings import setPlotSettings

setPlotSettings(font=True)

# %%
data = pd.read_csv('rfgrad_vs_absth_data.txt', sep=' ')

# %%
data
# Out:
#    absth  rfgrad       diff
# 0      0     0.0   0.090975
# 1      1     0.0   0.066600
# 2      2     0.0   0.088274
# 3      3     0.0   0.113619
# 4      4     0.0   0.472780
# 5     14     0.0   8.778200
# 6     24     0.0  14.328326
# 7     14    25.0  24.786312
# 8     14    12.5   1.478404

# %%
cmap = sns.color_palette("mako", as_cmap=True)
plt.scatter(data['absth'].values, data['rfgrad'].values, c=data['diff'].values, cmap=cmap)
plt.xlabel('Absorber thickness [mm]')
plt.ylabel('RF gradient [MV/m]')
plt.ylim((-0.9,25.5))
plt.colorbar(label='Difference [mm]');
