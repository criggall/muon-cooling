# %%
import numpy as np
import pandas as pd
import math
from matplotlib import pyplot as plt

import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(parent_dir)

from functions.read_g4bl_data import readTraceData

# %%
# Solenoid parameters:
L = 300 # mm
a = 360 # mm
b = 500 # mm
J = 80.46 # A/mm^2
pitch = 0.8 # degrees

# Constants:
mu0 = 1.2e-3 # kg*mm/s^2/A^2

# Define function to plot lines indicating solenoid placement:
def plot_solenoid(ax):
    ax.axvspan(xmin=-L/2, xmax=L/2, color='gray', alpha=0.1, zorder=-1)

# %% [markdown]
# ## Without solenoid pitch

# %%
# Read-in data:
data = readTraceData('ReferenceParticle_NoPitch.txt')

# %% [markdown]
# ### Particle tracking

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bx'])
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['By'])
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bz'])
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Analytical approach

# %%
# Analytical formula for B field from Fernow paper:
def B(z):
    B = mu0*J/2 * ( (L-z) * math.log( ( b + np.sqrt( b**2 + (L-z)**2 ) ) / ( a + np.sqrt( a**2 + (L-z)**2 ) ) ) + (L+z) * math.log( ( b + np.sqrt( b**2 + (L+z)**2 ) ) / ( a + np.sqrt( a**2 + (L+z)**2)) ) )
    return B

# %%
# Compute B with same z sampling:
Bx_vals, By_vals, Bz_vals = [], [], []
for z in data['z']:
    Bx_vals.append(0)
    By_vals.append(0)
    Bz = B(z)
    Bz_vals.append(Bz)

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], Bx_vals)
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], By_vals)
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], Bz_vals)
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Comparison

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bx'], label='simulation')
plt.plot(data['z'], Bx_vals, label='analytical')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.legend()
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['By'], label='simulation')
plt.plot(data['z'], By_vals, label='analytical')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.legend()
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bz'], label='simulation')
plt.plot(data['z'], Bz_vals, label='analytical')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## With solenoid pitch + neutral particle tracking

# %%
# Read-in data:
data2 = readTraceData('ReferenceParticle_Pitch.txt')

# %% [markdown]
# ### Particle tracking

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bx'])
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['By'])
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bz'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Analytical approach

# %%
# Compute B with same z sampling:
Bx_vals, By_vals, Bz_vals = [], [], []
for z in data2['z']:
    Bx_vals.append(0)
    By = -B(z)*np.sin(pitch*math.pi/180)
    By_vals.append(By)
    Bz = B(z)*np.cos(pitch*math.pi/180)
    Bz_vals.append(Bz)

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], Bx_vals)
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], By_vals)
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], Bz_vals)
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Comparison

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bx'], label='simulation')
plt.plot(data2['z'], Bx_vals, label='analytical')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.legend()
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['By'], label='simulation')
plt.plot(data2['z'], By_vals, label='analytical')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.legend()
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bz'], label='simulation')
plt.plot(data2['z'], Bz_vals, label='analytical')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.legend(loc='upper right')
plt.show()
