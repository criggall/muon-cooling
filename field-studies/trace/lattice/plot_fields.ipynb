# %%
import numpy as np
import pandas as pd
import math
from matplotlib import pyplot as plt

import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../../..'))
sys.path.append(parent_dir)

from functions.read_g4bl_data import readTraceData

# %%
# Solenoid parameters:
L = 300 # mm
a = 360 # mm
b = 500 # mm
J = 80.46 # A/mm^2
pitch = 0.8 # degrees
rolls = [240, 0, 120, 240, 0, 120] # degrees

# Channel parameters:
n = 6
spacing = 700

# Constants:
mu0 = 1.2e-3 # kg*mm/s^2/A^2

# Define function to plot lines indicating solenoid placement:
def plot_solenoid(ax):
    for i in range(n):
        if i%2 == 0: # positive polarity
            ax.axvspan(xmin=-L/2+i*spacing, xmax=L/2+i*spacing, color='gray', alpha=0.1, zorder=-1)
        elif i%2 == 1: # negative polarity
            ax.axvspan(xmin=-L/2+i*spacing, xmax=L/2+i*spacing, color='gray', alpha=0.2, zorder=-1)

# %% [markdown]
# ## Without solenoid pitches

# %% [markdown]
# ### Particle tracking

# %%
# Read-in data:
data = readTraceData('ReferenceParticle_NoPitch.txt')

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bx'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['By'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bz'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Analytical approach

# %%
# Analytical formula for B field from Fernow paper:
def B(z, J):
    ''' Note that z is defined as the axial distance from center of the solenoid '''
    B = mu0*J/2 * ( (L-z) * math.log( ( b + np.sqrt( b**2 + (L-z)**2 ) ) / ( a + np.sqrt( a**2 + (L-z)**2 ) ) ) + (L+z) * math.log( ( b + np.sqrt( b**2 + (L+z)**2 ) ) / ( a + np.sqrt( a**2 + (L+z)**2)) ) )
    return B

# %%
fig, ax = plt.subplots()

# Loop over solenoids:
df = pd.DataFrame({'z':pd.Series(dtype='float'), 'Bx':pd.Series(dtype='float'), 'By':pd.Series(dtype='float'), 'Bz':pd.Series(dtype='float')})
for i in range(n):

    # Field at one solenoid:
    z_vals, Bx_vals, By_vals, Bz_vals = [], [], [], []
    for j in range(len(data['z'])):
        if i%2 == 0: # positive polarity
            z = data['z'][j]
            z_vals.append(z+i*spacing)
            Bx_vals.append(0)
            By_vals.append(0)
            Bz_vals.append(B(z, J))
        elif i%2 == 1: # negative polarity
            z = data['z'][j]
            z_vals.append(z+i*spacing)
            Bx_vals.append(0)
            By_vals.append(0)
            Bz_vals.append(B(z, -J))
    df_temp = pd.DataFrame({'z' : z_vals, 'Bx' : Bx_vals, 'By' : By_vals, 'Bz' : Bz_vals})

    # Add to DataFrame with field components from all solenoids:
    df = pd.concat([df, df_temp], ignore_index=True)

    # Plot B_z vs. z for each solenoid:
    plt.plot(df_temp['z'], df_temp['Bz'])

plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()
    
# Sum all field components:
summed_df = df.groupby('z', as_index=False).sum()

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df['z'], summed_df['Bx'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df['z'], summed_df['By'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df['z'], summed_df['Bz'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Comparison

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bx'], label='simulation', color='tab:blue')
plt.plot(summed_df['z'], summed_df['Bx'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.legend()
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['By'], label='simulation', color='tab:blue')
plt.plot(summed_df['z'], summed_df['By'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.legend()
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data['z'], data['Bz'], label='simulation', color='tab:blue')
plt.plot(summed_df['z'], summed_df['Bz'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## With solenoid pitch + neutral particle tracking

# %%
# Read-in data:
data2 = readTraceData('ReferenceParticle_Pitch.txt')

# %% [markdown]
# ### Particle tracking

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bx'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['By'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bz'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Analytical approach

# %%
fig, ax = plt.subplots()

# Loop over solenoids:
df = pd.DataFrame({'z':pd.Series(dtype='float'), 'Bx':pd.Series(dtype='float'), 'By':pd.Series(dtype='float'), 'Bz':pd.Series(dtype='float')})
for i in range(n):

    # Field at one solenoid:
    z_vals, Bx_vals, By_vals, Bz_vals = [], [], [], []
    for j in range(len(data2['z'])):
        if i%2 == 0: # positive polarity
            J_temp = J
        elif i%2 == 1: # negative polarity
            J_temp = -J
        z = data2['z'][j]
        z_vals.append(z+i*spacing)
        Bx = 0
        Bx_vals.append(Bx)
        By = -B(z, J_temp)*np.sin(pitch*math.pi/180)
        By_vals.append(By)
        Bz = B(z, J_temp)*np.cos(pitch*math.pi/180)
        Bz_vals.append(Bz)
    df_temp = pd.DataFrame({'z' : z_vals, 'Bx' : Bx_vals, 'By' : By_vals, 'Bz' : Bz_vals})

    # Add to DataFrame with field components from all solenoids:
    df = pd.concat([df, df_temp], ignore_index=True)

    # Plot B_z vs. z for each solenoid:
    plt.plot(df_temp['z'], df_temp['By'])

plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()
    
# Sum all field components:
summed_df2 = df.groupby('z', as_index=False).sum()

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df2['z'], summed_df2['Bx'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df2['z'], summed_df2['By'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df2['z'], summed_df2['Bz'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Comparison

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bx'], label='simulation', color='tab:blue')
plt.plot(summed_df2['z'], summed_df2['Bx'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.legend(loc='upper right')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['By'], label='simulation', color='tab:blue')
plt.plot(summed_df2['z'], summed_df2['By'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.legend(loc='upper right')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data2['z'], data2['Bz'], label='simulation', color='tab:blue')
plt.plot(summed_df2['z'], summed_df2['Bz'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## With solenoid pitches and rolls + neutral particle tracking

# %%
# Read-in data:
data3 = readTraceData('ReferenceParticle_PitchRoll.txt')

# %% [markdown]
# ### Particle tracking

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data3['z'], data3['Bx'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data3['z'], data3['By'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data3['z'], data3['Bz'], color='tab:blue')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Analytical approach

# %%
fig, ax = plt.subplots()

# Loop over solenoids:
df = pd.DataFrame({'z':pd.Series(dtype='float'), 'Bx':pd.Series(dtype='float'), 'By':pd.Series(dtype='float'), 'Bz':pd.Series(dtype='float')})
for i in range(n):

    # Field at one solenoid:
    z_vals, Bx_vals, By_vals, Bz_vals = [], [], [], []
    for j in range(len(data2['z'])):
        if i%2 == 0: # positive polarity
            J_temp = J
        elif i%2 == 1: # negative polarity
            J_temp = -J
        z = data2['z'][j]
        z_vals.append(z+i*spacing)
        Bx = B(z, J_temp)*np.sin(pitch*math.pi/180)*np.sin(rolls[i]*math.pi/180)
        Bx_vals.append(Bx)
        By = -B(z, J_temp)*np.sin(pitch*math.pi/180)*np.cos(rolls[i]*math.pi/180)
        By_vals.append(By)
        Bz = B(z, J_temp)*np.cos(pitch*math.pi/180)
        Bz_vals.append(Bz)
    df_temp = pd.DataFrame({'z' : z_vals, 'Bx' : Bx_vals, 'By' : By_vals, 'Bz' : Bz_vals})

    # Add to DataFrame with field components from all solenoids:
    df = pd.concat([df, df_temp], ignore_index=True)

    # Plot B_z vs. z for each solenoid:
    plt.plot(df_temp['z'], df_temp['By'])

plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()
    
# Sum all field components:
summed_df3 = df.groupby('z', as_index=False).sum()

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df3['z'], summed_df3['Bx'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df3['z'], summed_df3['By'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(summed_df3['z'], summed_df3['Bz'], color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.show()

# %% [markdown]
# ### Comparison

# %%
# Plot B_x vs. z:
fig, ax = plt.subplots()
plt.plot(data3['z'], data3['Bx'], label='simulation', color='tab:blue')
plt.plot(summed_df3['z'], summed_df3['Bx'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_x$ [T]')
plt.legend(loc='upper right')
plt.show()

# %%
# Plot B_y vs. z:
fig, ax = plt.subplots()
plt.plot(data3['z'], data3['By'], label='simulation', color='tab:blue')
plt.plot(summed_df3['z'], summed_df3['By'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_y$ [T]')
plt.legend(loc='upper right')
plt.show()

# %%
# Plot B_z vs. z:
fig, ax = plt.subplots()
plt.plot(data3['z'], data3['Bz'], label='simulation', color='tab:blue')
plt.plot(summed_df3['z'], summed_df3['Bz'], label='analytical', color='tab:green')
plot_solenoid(ax)
plt.xlabel('$z$ [mm]')
plt.ylabel('$B_z$ [T]')
plt.legend(loc='upper right')
plt.show()
