# %%
import numpy as np
from matplotlib import pyplot as plt
import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)
from functions.read_icool_data import readECALC9
from functions.read_icool_data import readECALC9F
from functions.read_icool_data import readEMITCALC
from functions.set_plot_settings import setPlotSettings
setPlotSettings(font=True)

# %%
# Define function to compute factor of emittance reduction:
def emittanceFactor(initial_emittances, final_emittances):
    ''' Input initial and final emittances as vectors '''
    factors = []
    for i in range(len(initial_emittances)):
        factors.append(initial_emittances[i]/final_emittances[i])
    return factors

# %% [markdown]
# ### ECALC9

# %%
# Read in data from ECALC9:
data9 = readECALC9('ecalc9.out')

# %%
# Plot beta vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9['z'][0], data9['beta'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta$ (m)')
plt.show()

# %%
# Plot longitudinal beta vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9['z'][0], data9['betaL'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta_L$ (m)')
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9['z'][0], data9['eperp'][0], label='$\epsilon_{\perp}$', color='blue', marker='.', markersize=5)
plt.plot(data9['z'][0], data9['elong'][0], label='$\epsilon_L$', color='green', marker='.', markersize=5)
plt.plot(data9['z'][0], data9['e6D'][0], label='$\epsilon_{6D}$', color='black', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot e_long vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9['z'][0], data9['elong'][0], color='green', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_L$ (m)')
plt.show()

# %%
# Plot e_perp vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9['z'][0], data9['eperp'][0], color='blue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_{\perp}$ (m)')
plt.show()

# %%
# Plot 6D emittance vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9['z'][0], data9['e6D'][0], color='black', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_{6D}$ (m$^3$)')
plt.show()

# %%
# Calculate transverse emittance and expected 6D emittance:
trans_emit = []
emit_prod = []
for i in range(len(data9['eperp'])):
    eperp = data9['eperp'][i]; elong=data9['elong'][i]
    trans_emit.append(eperp**2)
    emit_prod.append(eperp**2*elong)

# Plot 6D emittance:
plt.figure(figsize=(9,5))
plt.plot(data9['z'][0], emit_prod[0], label='$\epsilon_{\perp}^2\epsilon_{L}$', marker='.', markersize=5)
plt.plot(data9['z'][0], data9['e6D'][0], label='$\epsilon_{6D}$', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m$^3$)')
plt.legend()
plt.show()

# %%
# Compute emittance reduction factors:
print('Initial/final eperp: ' + str(emittanceFactor([data9['eperp'][0][0]], [data9['eperp'][0][len(data9['eperp'][0])-1]])[0]))
print('Initial/final elong: ' + str(emittanceFactor([data9['elong'][0][0]], [data9['elong'][0][len(data9['elong'][0])-1]])[0]))
print('Initial/final e6D: ' + str(emittanceFactor([data9['e6D'][0][0]], [data9['e6D'][0][len(data9['e6D'][0])-1]])[0]))
# Out:
# Initial/final eperp: 4.669753838654643
# Initial/final elong: 2.732552215995925
# Initial/final e6D: 51.86142709410548

# %% [markdown]
# ### ECALC9F

# %%
# Read in data from ECALC9F:
data9f = readECALC9F('ecalc9f.dat')

# %%
# Plot beta vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9f['z'][0], data9f['beta'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta$ (m)')
plt.show()

# %%
# Plot longitudinal beta vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9f['z'][0], data9f['betaL'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta_L$ (m)')
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9f['z'][0], data9f['eperp'][0], label='$\epsilon_{\perp}$', color='blue', marker='.', markersize=5)
plt.plot(data9f['z'][0], data9f['elong'][0], label='$\epsilon_L$', color='green', marker='.', markersize=5)
plt.plot(data9f['z'][0], data9f['e6D'][0], color='black', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot e_long vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9f['z'][0], data9f['elong'][0], color='green', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_L$ (m)')
plt.show()

# %%
# Plot e_perp vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9f['z'][0], data9f['eperp'][0], color='blue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_{\perp}$ (m)')
plt.show()

# %%
# Plot 6D emittance vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(data9f['z'][0], data9f['e6D'][0], color='black', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_{6D}$ (m$^3$)')
plt.show()

# %%
# Calculate transverse emittance and expected 6D emittance:
trans_emit = []
emit_prod = []
for i in range(len(data9f['eperp'])):
    eperp = data9f['eperp'][i]; elong=data9f['elong'][i]
    trans_emit.append(eperp**2)
    emit_prod.append(eperp**2*elong)

# Plot 6D emittance:
plt.figure(figsize=(9,5))
plt.plot(data9f['z'][0], emit_prod[0], label='$\epsilon_{\perp}^2\epsilon_{L}$', marker='.', markersize=5)
plt.plot(data9f['z'][0], data9f['e6D'][0], label='$\epsilon_{6D}$', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m$^3$)')
plt.legend()
plt.show()

# %%
# Compute emittance reduction factors:
print('Initial/final eperp: ' + str(emittanceFactor([data9f['eperp'][0][0]], [data9f['eperp'][0][len(data9f['eperp'][0])-1]])[0]))
print('Initial/final elong: ' + str(emittanceFactor([data9f['elong'][0][0]], [data9f['elong'][0][len(data9f['elong'][0])-1]])[0]))
print('Initial/final e6D: ' + str(emittanceFactor([data9f['e6D'][0][0]], [data9f['e6D'][0][len(data9f['e6D'][0])-1]])[0]))
# Out:
# Initial/final eperp: 4.7274917193616375
# Initial/final elong: 5.917255594817432
# Initial/final e6D: 151.2796462548573

# %% [markdown]
# ### EMITCALC

# %%
# Read in data from EMITCALC:
dataemit = readEMITCALC('emitcalc.out')
# dataemit = readEMITCALC('emitcalc_with_beamstart.out')

# %%
# Plot Dx vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['Dx'][0], marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$D_x$ (m)')
plt.show()

# %%
# Plot Dy vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['Dy'][0], marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$D_y$ (m)')
plt.show()

# %%
D_vals = []
for i in range(len(dataemit['z'][0])):
    D_vals.append(np.sqrt(dataemit['Dx'][0][i]**2 + dataemit['Dy'][0][i]**2))

# %%
# Plot D vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], D_vals, marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$D$ (m)')
plt.show()

# %%
# Plot beta vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['beta'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta$ (m)')
plt.show()

# %%
# Plot longitudinal beta vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['betaL'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta_L$ (m)')
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['eperp'][0], label='$\epsilon_{\perp}$', color='blue', marker='.', markersize=5)
plt.plot(dataemit['z'][0], dataemit['elong'][0], label='$\epsilon_L$', color='green', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot e_long vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['elong'][0], color='green', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_L$ (m)')
plt.show()

# %%
# Plot e_perp vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['eperp'][0], color='blue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_{\perp}$ (m)')
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['emit1'][0], label='$\epsilon_1$', color='tab:red', marker='.', markersize=5)
plt.plot(dataemit['z'][0], dataemit['emit2'][0], label='$\epsilon_2$', color='tab:green', marker='.', markersize=5)
plt.plot(dataemit['z'][0], dataemit['emit3'][0], label='$\epsilon_3$', color='tab:blue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot larger mode vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['emit3'][0], label='$\epsilon_3$', color='tab:blue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot two smaller modes vs. z:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['emit1'][0], label='$\epsilon_1$', color='tab:red', marker='.', markersize=5)
plt.plot(dataemit['z'][0], dataemit['emit2'][0], label='$\epsilon_2$', color='tab:green', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot all three modes scaled to fit on one plot:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(dataemit['z'][0], dataemit['emit1'][0], label=r'$\varepsilon_1$', color='tab:red', marker='.', markersize=5)
plt.plot(dataemit['z'][0], dataemit['emit2'][0], label=r'$\varepsilon_2$', color='tab:green', marker='.', markersize=5)
plt.plot(dataemit['z'][0], dataemit['emit3'][0]/200, label=r'$\varepsilon_3/200$', color='tab:blue', marker='.', markersize=5)
plt.xlabel('$z$ [m]')
plt.ylabel(r'$\varepsilon$ [m]')
plt.legend()
plt.show()

# %%
plt.rcParams.update({'font.size': 20})

# Subplot sqrt(eps1*eps2) and eps3:
fig, ax = plt.subplots(figsize=(9,5))
vals = np.sqrt(dataemit['emit1'][0]*dataemit['emit2'][0])
plt.plot(dataemit['z'][0], vals, label=r'$\sqrt{\varepsilon_1\varepsilon_2}$', marker='.', markersize=5)
plt.plot(dataemit['z'][0], dataemit['emit3'][0]/200, label=r'$\varepsilon_3/200$',  marker='.', markersize=5)
plt.xlabel('$z$ [m]')
plt.ylabel(r'$\varepsilon$ [m]')
plt.legend()
plt.tight_layout()
plt.savefig('emittance.pdf')
plt.show()

# %%
# Initial and final emittances:
print('Initial eperp: ' + str(dataemit['eperp'][0][0]))
print('Final eperp: ' + str(dataemit['eperp'][0][len(dataemit['eperp'][0])-1]))
print('Initial elong: ' + str(dataemit['elong'][0][0]))
print('Final elong: ' + str(dataemit['elong'][0][len(dataemit['elong'][0])-1]))
# Out:
# Initial eperp: 0.01604
# Final eperp: 0.003595
# Initial elong: 5.748
# Final elong: 2.908

# %%
# Compute emittance reduction factors:
print('Initial/final eperp: ' + str(emittanceFactor([dataemit['eperp'][0][0]], [dataemit['eperp'][0][len(dataemit['eperp'][0])-1]])[0]))
print('Initial/final elong: ' + str(emittanceFactor([dataemit['elong'][0][0]], [dataemit['elong'][0][len(dataemit['elong'][0])-1]])[0]))
# Out:
# Initial/final eperp: 4.461752433936022
# Initial/final elong: 1.9766162310866577

# %%
# Compute emittance reduction factors:
print('Initial/final e1: ' + str(emittanceFactor([dataemit['emit1'][0][0]], [dataemit['emit1'][0][len(dataemit['emit1'][0])-1]])[0]))
print('Initial/final e2: ' + str(emittanceFactor([dataemit['emit2'][0][0]], [dataemit['emit2'][0][len(dataemit['emit2'][0])-1]])[0]))
print('Initial/final e3: ' + str(emittanceFactor([dataemit['emit3'][0][0]], [dataemit['emit3'][0][len(dataemit['emit3'][0])-1]])[0]))
# Out:
# Initial/final e1: 2.643295803480041
# Initial/final e2: 7.698019801980197
# Initial/final e3: 1.9766162310866577

# %% [markdown]
# ### Values from paper

# %%
# Compute emittance reduction factor from values reported in paper:
initial_e6D = 5.6
final_e6D = 0.051
print(initial_e6D/final_e6D)
# Out:
# 109.80392156862744

# %%
# Load digitized emittance data from paper:
paper_data_dir = '../paper-data/'
data_long = np.genfromtxt(paper_data_dir+'paper_emitlong_vs_z.csv',delimiter=',')
z_long = [i[0] for i in data_long]
e_long = [i[1] for i in data_long]
data_trans1 = np.genfromtxt(paper_data_dir+'paper_emittrans1_vs_z.csv',delimiter=',')
z_trans1 = [i[0] for i in data_trans1]
e_trans1 = [i[1] for i in data_trans1]
data_trans2 = np.genfromtxt(paper_data_dir+'paper_emittrans2_vs_z.csv',delimiter=',')
z_trans2 = [i[0] for i in data_trans2]
e_trans2 = [i[1] for i in data_trans2]

# %%
# Plot emittances from paper:
fig, ax = plt.subplots(figsize=(9,5))
plt.plot(z_long, e_long, marker='.', markersize=5, color='tab:red', label='longitudinal')
plt.plot(z_trans1, e_trans1, marker='.', markersize=5, color='tab:blue', label='transverse 1')
plt.plot(z_trans2, e_trans2, marker='.', markersize=5, color='tab:green', label='transverse 2')
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\varepsilon$ (cm)')
plt.legend()
plt.show()

# %%
# Compute emittance reduction factors:
factor1 = emittanceFactor([e_trans1[0]], [e_trans1[len(e_trans1)-1]])[0]
factor2 = emittanceFactor([e_trans2[0]], [e_trans2[len(e_trans2)-1]])[0]
print('Initial/final transverse 1: ' + str(factor1))
print('Initial/final transverse 2: ' + str(factor2))
print('Initial/final longitudinal: ' + str(emittanceFactor([e_long[0]], [e_long[len(elong)-1]])[0]))
# Out:
# Initial/final transverse 1: 5.748920650447747
# Initial/final transverse 2: 7.410537497344523
# Initial/final longitudinal: 1.162467585281155
