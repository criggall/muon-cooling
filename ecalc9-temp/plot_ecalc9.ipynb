# %%
import numpy as np
from matplotlib import pyplot as plt
import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)
from functions.read_ecalc9_data import readECALC9
from functions.read_ecalc9_data import readECALC9F
from functions.read_ecalc9_data import readEMITCALC

# %%
# Plot solenoids?
do_sol_plot = False

# Number of solenoids:
n = 18

# Distance between solenoids:
d = 0.7 # m

# Solenoid length:
L = 0.3 # m

# Define function to plot lines indicating solenoid placement:
def plotSolenoids(ax):
    for i in range(n):
        center = 0.5+i*d
        if np.mod(i,2) == 0:
            ax.axvspan(xmin=center-L/2, xmax=center+L/2, color='gray', alpha=0.1)
        else:
            ax.axvspan(xmin=center-L/2, xmax=center+L/2, color='gray', alpha=0.2)

# %% [markdown]
# ### ECALC9

# %%
# Read in data from ECALC9:
data9 = readECALC9('ecalc9.out')
# Out:
# /Users/criggall/Documents/muon-cooling/functions/read_ecalc9_data.py:17: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, skiprows=12, names=column_names)

# %%
# Plot Bz vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(data9['z'][0], data9['Bz'][0], marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$B_z$ (T)')
plt.show()

# %%
# Plot beta vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(data9['z'][0], data9['beta'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta$ (m)')
plt.show()

# %%
# Plot longitudinal beta vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(data9['z'][0], data9['betaL'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta_L$ (m)')
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.scatter(data9['z'], data9['eperp'], s=5, label='$\epsilon_{\perp}$', color='blue')
plt.scatter(data9['z'], data9['elong'], s=5, label='$\epsilon_L$', color='green')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot 6D emittance vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.scatter(data9['z'], data9['e6D'], s=5, color='black')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_{6D}$ (m$^3$)')
plt.show()

# %%
# Calculate transverse emittance and expected 6D emittance:
trans_emit = []
emit_prod = []
for i in range(len(data9['eperp'])):
    eperp = data9['eperp'][i]; elong=data9['elong'][i]
    trans_emit.append(eperp**2)
    emit_prod.append(eperp**2*elong)

# Plot 6D emittance:
plt.figure(figsize=(12,5))
plt.scatter(data9['z'], emit_prod, s=5, label='$\epsilon_{\perp}^2\epsilon_{L}$')
plt.scatter(data9['z'], data9['e6D'], s=5, label='$\epsilon_{6D}$')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m$^3$)')
plt.legend()
plt.show()

# %% [markdown]
# ### ECALC9F

# %%
# Read in data from ECALC9F:
data9f = readECALC9F('ecalc9f.dat')
# Out:
# /Users/criggall/Documents/muon-cooling/functions/read_ecalc9_data.py:43: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, skiprows=13, names=column_names)

# %%
# Plot Bz vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(data9f['z'][0], data9f['Bz'][0], marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$B_z$ (T)')
plt.show()

# %%
# Plot beta vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(data9f['z'][0], data9f['beta'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta$ (m)')
plt.show()

# %%
# Plot longitudinal beta vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(data9f['z'][0], data9f['betaL'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta_L$ (m)')
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.scatter(data9f['z'], data9f['eperp'], s=5, label='$\epsilon_{\perp}$', color='blue')
plt.scatter(data9f['z'], data9f['elong'], s=5, label='$\epsilon_L$', color='green')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot 6D emittance vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.scatter(data9f['z'], data9f['e6D'], s=5, color='black')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon_{6D}$ (m$^3$)')
plt.show()

# %%
# Calculate transverse emittance and expected 6D emittance:
trans_emit = []
emit_prod = []
for i in range(len(data9f['eperp'])):
    eperp = data9f['eperp'][i]; elong=data9f['elong'][i]
    trans_emit.append(eperp**2)
    emit_prod.append(eperp**2*elong)

# Plot 6D emittance:
plt.figure(figsize=(12,5))
plt.scatter(data9f['z'], emit_prod, s=5, label='$\epsilon_{\perp}^2\epsilon_{L}$')
plt.scatter(data9f['z'], data9f['e6D'], s=5, label='$\epsilon_{6D}$')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m$^3$)')
plt.legend()
plt.show()

# %% [markdown]
# ### EMITCALC

# %%
# Read in data from EMITCALC:
dataemit = readEMITCALC('emitcalc.out')
# Out:
# /Users/criggall/Documents/muon-cooling/functions/read_ecalc9_data.py:69: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True, skiprows=15, names=column_names)

# %%
# Plot Bz vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(dataemit['z'][0], dataemit['Bz0'][0], marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel('$B_z$ (T)')
plt.show()

# %%
# Plot beta vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(dataemit['z'][0], dataemit['beta'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta$ (m)')
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.scatter(dataemit['z'], dataemit['eperp'], s=5, label='$\epsilon_{\perp}$', color='blue')
plt.scatter(dataemit['z'], dataemit['elong'], s=5, label='$\epsilon_L$', color='green')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot emittances vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.scatter(dataemit['z'], dataemit['emit1'], s=5, label='$\epsilon_1$', color='tab:red')
plt.scatter(dataemit['z'], dataemit['emit2'], s=5, label='$\epsilon_2$', color='tab:green')
plt.scatter(dataemit['z'], dataemit['emit3'], s=5, label='$\epsilon_3$', color='tab:blue')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot emittances vs. z -- isolating the two smaller components:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.scatter(dataemit['z'], dataemit['emit1'], s=5, label='$\epsilon_1$', color='tab:red')
plt.scatter(dataemit['z'], dataemit['emit2'], s=5, label='$\epsilon_2$', color='tab:green')
plt.xlabel('$z$ (m)')
plt.ylabel('$\epsilon$ (m)')
plt.legend()
plt.show()

# %%
# Plot longitudinal beta vs. z:
fig, ax = plt.subplots(figsize=(12,5))
if do_sol_plot == True:
    plotSolenoids(ax)
plt.plot(dataemit['z'][0], dataemit['betaL'][0], color='darkblue', marker='.', markersize=5)
plt.xlabel('$z$ (m)')
plt.ylabel(r'$\beta_L$ (m)')
plt.show()
