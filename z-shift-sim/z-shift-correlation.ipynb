# %%
from matplotlib import pyplot as plt

# %%
# Z offset values:
# steps = 10
# increment = 1 #cm
# val = 0
# z_shift = []
# for i in range(steps):
#     z_shift.append(val)
#     val += increment
# print(z_shift)

z_shift = [0, 10, 20, 30, 40, 50] #cm

# %%
# Mean positions of initial and final distributions -- copy from plotter.ipynb:
pi_shift = [1.849054470682873, 1.8342649224632548, 1.8176265371505815, 1.8016705581320747, 1.7826838238110216, 1.7654858713367838]
pf_shift = [1.1802624214446487, 1.1500500021815467, 1.1291702985810377, 1.0886267002156231, 1.0477796972806812, 1.0267574780352382]

# %%
plt.plot(z_shift,pi_shift,color='blue',label='initial',marker='.')
plt.plot(z_shift,pf_shift,color='red',label='final',marker='.')
plt.xlabel('initial beam z offset (cm)')
plt.ylabel('mean p total position (cm)')
plt.legend()

# %%
plt.plot(z_shift,pi_shift,color='blue',label='initial',marker='.')
plt.xlabel('initial beam z offset (cm)')
plt.ylabel('mean p total position (cm)')
plt.title('intial distribution')
# Out:
# Text(0.5, 1.0, 'intial distribution')

# %%
plt.plot(z_shift,pf_shift,color='red',label='final',marker='.')
plt.xlabel('initial beam z offset (cm)')
plt.ylabel('mean p total position (cm)')
plt.title('final distribution')
# Out:
# Text(0.5, 1.0, 'final distribution')
