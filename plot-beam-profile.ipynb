# %%
# Import libraries:
import numpy as np
from matplotlib import pyplot as plt

# Load data from txt file:
file = 'Yuri-David-File/G4bl-Output/profile.txt'
data = np.loadtxt(file)

# %%
# Values along channel:
Z = []
emitX = []
emitY = []
emitZ = []
for i in range(len(data)):
    Z.append(data[i][0])
    emitX.append(data[i][6])
    emitY.append(data[i][7])
    emitZ.append(data[i][8])

# %%
# Plot emittance along z:
plt.figure()
plt.scatter(Z,emitX,color='red',label='x',s=0.1)
plt.scatter(Z,emitY,color='blue',label='y',s=0.1)
plt.scatter(Z,emitZ,color='green',label='z',s=0.1)
plt.xlabel('z (mm)')
plt.ylabel('emittance (mm)')
plt.legend()
plt.show()
