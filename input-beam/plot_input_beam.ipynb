# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# Define input beam file:
file = 'input.dat'

# %%
# Read in data from file:

df = pd.read_csv(file, comment='#', delim_whitespace=True, 
                 names=["x", "y", "z", "Px", "Py", "Pz", "t", "PDGid", "EventID", "TrackID", "ParentID", "Weight"])

px = df["Px"].to_numpy()
py = df["Py"].to_numpy()
pz = df["Pz"].to_numpy()

ptotal = []
for i in range(len(px)):
    ptotal.append(np.sqrt(px[i]**2+py[i]**2+pz[i]**2))
# Out:
# /var/folders/c9/q_ds728s44z0_fjv35nz68ym0000gn/T/ipykernel_46179/4125229367.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, comment='#', delim_whitespace=True,

# %%
# Plot distribution:
plt.hist(ptotal,color='green',range=(0,400),bins=80)
plt.xlabel('$p_{total}$ (MeV/c)',loc='right')
plt.ylabel('Events',loc='top')
plt.show()
